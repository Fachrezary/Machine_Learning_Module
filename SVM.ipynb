# %% [markdown]
# # Fachreza Riyanda (202131116)

# %% [markdown]
# ## Import Library

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Membaca dan Menampilkan Data

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
from sklearn.preprocessing import LabelEncoder
for col in ['BMI', 'DiabetesPedigreeFunction', 'Outcome']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    df
    print (df['BMI'].unique(), df['DiabetesPedigreeFunction'].unique(), df['Outcome'].unique())
# Out:
# [123  62  30  77 209  53 103 140  99   0 163 167  67  95  54  94 227  90
#  211 133 180 141 185  86 153 104 181  29  20 128 147 107  45   8  72  37
#  120 118 169 158 127 189  25 223  70 200  91  76 178   5  39  41 124 134
#   27 164 233 190 198  47  51 117 114 206   7  85  82 212 138 109  44 115
#  210  22  88  43 236 113 172  61   3 232  35 126  11  83 239 177  57  23
#  183  89 130 161 121 105  78 243 129  64 244 208 132  75 170  14 125 101
#  156 182  69  18 191 234 240  49 194 159 217  93 108  80 213 116 247 220
#  136  73 146  24 119  98 241  40  26 135 102 188  36 162 142 207 205 199
#  145 165  84  33 144 154 221 215 229 137 214 216   2  87  55 110 150 187
#   48  71 225  74  46  50 166  66  56 174  12 148 100 112 242  13 184  52
#   58   4 168  32 224  28 186 155  17 195 202 131  68 152  92 179 171 149
#  235   9  21 226  34  19 201 204   1  60 222 157  42 111 246  15  63  96
#  228 197 175 139 203 192 231 122 160  97  59  16 151  81  65 173 106   6
# ...

# %% [markdown]
# ## Data Drop

# %%
x = df.drop(['Outcome' ], axis = 1)
y = df['Outcome']

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0              6      148             72             35        0  123
# 1              1       85             66             29        0   62
# 2              8      183             64              0        0   30
# 3              1       89             66             23       94   77
# 4              0      137             40             35      168  209
# ..           ...      ...            ...            ...      ...  ...
# 763           10      101             76             48      180  118
# 764            2      122             70             27        0  155
# 765            5      121             72             23      112   58
# 766            1      126             60              0        0   95
# 767            1       93             70             31        0   98
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                         350   50        1
# ...

# %% [markdown]
# ## Pembagian Data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Model SVM

# %%
from sklearn.svm import SVC

model = SVC(random_state=0)
model.fit(x_train, y_train)
# Out:
# SVC(random_state=0)

# %% [markdown]
# ## Prediksi

# %%
predict = model.predict(x_test)

# %%
x_test.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 661            1      199             76             43        0  208
# 122            2      107             74             30      100  123
# 113            4       76             62              0        0  127
# 14             5      166             72             19      175   54
# 529            0      111             65              0        0   43
# ..           ...      ...            ...            ...      ...  ...
# 476            2      105             80             45      191  124
# 482            4       85             58             22       49   74
# 230            4      142             86              0        0  215
# 527            3      116             74             15      105   59
# 380            1      107             72             30       82  101
#
#      DiabetesPedigreeFunction  Age
# ...

# %% [markdown]
# ## Visualisasi Model : Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, predict)
display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
display.plot()
plt.show()

# %% [markdown]
# ## Model Evaluasi

# %%
from sklearn.metrics import accuracy_score
print("SVM Accuracy Score :", accuracy_score
      
      (y_test,predict) * 100,"%")
# Out:
# SVM Accuracy Score : 77.92207792207793 %
